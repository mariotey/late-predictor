# %%
import requests
url = "https://late-predictor.onrender.com/predict"

payload = {
    "day_of_week": 4,
    "distance_km": 2.1,
    "category": "dinner/drinks"
}

headers = {
    "Content-Type": "application/json"
}

response = requests.post(url, json=payload, headers=headers)

response.json()
# Out:
# {'prediction': 32.66708154633146, 'models_used': ['random_forest', 'gboost']}
