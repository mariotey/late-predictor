# %%
import sys
import os

sys.path.append(os.path.abspath(".."))

# %%
import requests

FASTAPI_URL = "https://late-predictor.onrender.com/"

# %% [markdown]
# ### Example of a Prediction Inferencing

# %%
url = f"{FASTAPI_URL}/predict"

payload = {
    "datetime_val": "2026-05-06T15:30:00Z",
    "init_latlon": [1.3, 103.8],
    "dest_latlon": [1.35, 103.9],
    "category": "dinner"
}

response = requests.post(url, json=payload)

print(response.status_code)
print(response.json())
# Out:
# 500
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\requests\models.py:978, in Response.json(self, **kwargs)
#     977 try:
# --> 978     return complexjson.loads(self.text, **kwargs)
#     979 except JSONDecodeError as e:
#     980     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     981     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\json\__init__.py:352, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     349 if (cls is None and object_hook is None and
#     350         parse_int is None and parse_float is None and
#     351         parse_constant is None and object_pairs_hook is None and not kw):
# --> 352     return _default_decoder.decode(s)
#     353 if cls is None:
#
# File c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\json\decoder.py:345, in JSONDecoder.decode(self, s, _w)
#     341 """Return the Python representation of ``s`` (a ``str`` instance
#     342 containing a JSON document).
#     343
#     344 """
# --> 345 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     346 end = _w(s, end).end()
#
# File c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\json\decoder.py:363, in JSONDecoder.raw_decode(self, s, idx)
#     362 except StopIteration as err:
# --> 363     raise JSONDecodeError("Expecting value", s, err.value) from None
#     364 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[5], line 13
#       9
#      10 response = requests.post(url, json=payload)
#      11
#      12 print(response.status_code)
# ---> 13 print(response.json())
#
# File c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\requests\models.py:982, in Response.json(self, **kwargs)
#     978     return complexjson.loads(self.text, **kwargs)
#     979 except JSONDecodeError as e:
#     980     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     981     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 982     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %% [markdown]
# ### Example of a Feedback

# %%
url = f"{FASTAPI_URL}/feedback"

payload = {
    "meeting_location": "Bukit Panjang Plaza",
    "meeting_datetime":"2026-05-06T15:30:00Z",
    "init_latlon":[1.3, 103.8],
    "meeting_latlon":[1.35, 103.9],
    "category":"dinner",
    "pred_min":19,
    "arrived_datetime":"2026-05-06T18:30:00Z"
}

response = requests.post(url, json=payload)

print(response.status_code)
print(response.json())
# Out:
# 200
# {'status': 'Feedback received'}
